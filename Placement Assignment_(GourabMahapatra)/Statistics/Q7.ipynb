# %% [markdown]
# Q-7. The equations of two lines of regression, obtained in a correlation analysis
# between variables X and Y are as follows:
#
# 2𝑋 + 3 − 8 = 0 and 2𝑌 + 𝑋 − 5 = 0 The variance of 𝑋 = 4 Find the
#
#     a. Variance of Y
#     b. Coefficient of determination of C and Y
#     c. Standard error of estimate of X on Y and of Y on X.

# %% [markdown]
# **Ans 7:** To solve the problem, let's analyze the given regression equations:
#
#     Equation 1: 2X + 3Y - 8 = 0
#     Equation 2: 2Y + X - 5 = 0
#
# We can rewrite Equation 1 as:
#
#     3Y = 8 - 2X
#     Y = (8 - 2X) / 3
#
# Now, we substitute the value of Y from Equation 1 into Equation 2:
#
#     2[(8 - 2X) / 3] + X - 5 = 0
#     (16 - 4X) / 3 + X - 5 = 0
#     16 - 4X + 3X - 15 = 0
#     -X + 1 = 0
#     X = 1
#
# Now that we have the value of X, we can substitute it back into Equation 1 to find Y:
#
#     2(1) + 3Y - 8 = 0
#     2 + 3Y - 8 = 0
#     3Y - 6 = 0
#     3Y = 6
#     Y = 2
#
# a. Variance of Y:
#
# The variance of X is given as 4. To find the variance of Y, we need to calculate the sum of squares of the differences between
# each Y value and the mean of Y.
#
# The mean of Y can be found using the given regression equation:
#
#     Y = (8 - 2X) / 3
#     Y = (8 - 2(1)) / 3
#     Y = 6/3
#     Y = 2
#
# Now, calculate the variance of Y:
#
# Variance of Y = Σ(Y - Y_mean)^2 / n
#
# Since we only have one data point for Y (Y = 2), the variance is zero.
#
# b. Coefficient of determination between X and Y:
#
# The coefficient of determination (R^2) measures the proportion of the total variation in the dependent variable (Y) that can be explained by the independent variable (X).
#
# To calculate the coefficient of determination, we need the total sum of squares (SST), regression sum of squares (SSR), and residual sum of squares (SSE).
#
#     SST = Σ(Y - Y_mean)^2
#     SSR = Σ(Y_predicted - Y_mean)^2
#     SSE = Σ(Y - Y_predicted)^2
#
# The coefficient of determination is given by:
#
#     R^2 = SSR / SST
#
# Since we only have one data point for Y, all the sums will be zero. Therefore, the coefficient of determination is also zero.
#
# c. Standard error of estimate of X on Y and Y on X:
#
# The standard error of estimate (SEE) measures the average deviation of the observed Y values from the predicted Y values (from the regression line).
#
# To calculate the standard error of estimate of X on Y, we use the regression equation for X on Y:
#
#     2X + 3Y - 8 = 0
#     2X + 3(2) - 8 = 0
#     2X + 6 - 8 = 0
#     2X - 2 = 0
#     2X = 2
#     X = 1
#
# The standard error of estimate of X on Y is given by:
#
#     SEE(X|Y) = sqrt(SSE_X|Y / (n - 2))
#
# Since we only have one data point, n = 1. Therefore, the standard error of estimate of X on Y is undefined.
#
# Similarly, to calculate the standard error of estimate of Y on X, we use the regression equation for Y on X:
#
#     2Y + X - 5 = 0
#     2Y + 1 - 5 = 0
#     2Y - 4 = 0
#     2Y = 4
#     Y = 2
#
# The standard error of estimate of Y on X is given by:
#
#     SEE(Y|X) = sqrt(SSE_Y|X / (n - 2))
#
# Since we only have one data point, n = 1. Therefore, the standard error of estimate of Y on X is undefined.
#
# In summary:
#
#     a. Variance of Y = 0
#     b. Coefficient of determination (R^2) = 0
#     c. Standard error of estimate:
#        - SEE(X|Y) = undefined
#        - SEE(Y|X) = undefined
